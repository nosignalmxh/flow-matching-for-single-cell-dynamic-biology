# %% [markdown]
# # Chapter 3 retired index
#
# The old monolithic Chapter 3 notebook is retired. Use the maintained split tutorial notebooks instead:
#
# - `chapter3_1_flow_matching_from_scratch.ipynb` for the toy CFM from-scratch tutorial.
# - `chapter3_2_eb_flow_matching.ipynb` for EB main training, cache, sampling, and Euler sensitivity.
# - `chapter3_3_eb_ablations.ipynb` for baselines, ablations, paper-table export, artifact index, and claim audit.
#
# The complete retired monolith is preserved for artifact-contract checks at `archive/notebooks_retired_20260604_ch03_split/03_flow_matching_from_scratch.ipynb`. This index intentionally contains no experiment code and must not be used to regenerate Chapter 3 artifacts.
