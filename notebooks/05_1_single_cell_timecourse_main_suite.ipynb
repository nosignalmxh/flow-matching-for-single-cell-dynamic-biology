# %% [markdown]
# # Section 5.1 Single-cell time-course main suite
#
# This notebook reproduces the Section 5.1 EB time-course main suite as a tutorial. The aim is not only to regenerate the tables and Figure 5.1, but to show how the experiment is assembled: which time points are observed, which point is hidden, how local and shared bridges differ, and how endpoint metrics connect to the paper-facing claim table.

# %% [markdown]
# ## 1. What this experiment tests
#
# The EB data contain single-cell snapshots at five ordered time points. We train flow-matching bridges from the initial snapshot and ask two complementary questions:
#
# - Can a model recover the hidden intermediate population at `t2`?
# - Can a model roll out to the seen endpoint `t4` without accumulating too much long-horizon error?
# - Are velocities smooth across hand-off points where pairwise local bridges switch from one local model to the next?
#
# The comparison is deliberately small: pairwise local bridges, one shared adjacent-only field, and two shared fields that also see skip pairs.

# %% [markdown]
# ## 2. Setup and reproducibility controls
#
# The setup cell keeps only environment and import mechanics. Reusable path, IO, display, plotting, and audit helpers live in `src.timecourse_reporting`; the experimental steps below remain visible in this notebook.

# %%
import os
os.environ.setdefault("MPLCONFIGDIR", "/tmp/mplconfig_ch05_section51")

from pathlib import Path
import sys

candidate_roots = [
    Path.cwd().resolve(),
    Path.cwd().resolve().parent,
    Path("/home/xmabs/flow_matching_for_dynamic_biology/flow_matching_for_dynamic_biology"),
    Path("/import/home4/xmabs/flow_matching_for_dynamic_biology/flow_matching_for_dynamic_biology"),
]
PROJECT_ROOT = next(
    candidate for candidate in candidate_roots
    if (candidate / "src" / "single_cell_experiments.py").exists()
)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: /import/macyang_home4/xmabs/flow_matching_for_dynamic_biology/flow_matching_for_dynamic_biology

# %%
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

from src.single_cell_experiments import (
    _global_rollout,
    _local_sequence_rollout,
    _train_global_bridge_model,
    _train_local_bridge,
    build_ch05_section51_main_text_results,
    endpoint_distribution_metrics,
    load_eb_ch05,
    set_global_seed,
    summarize_eb_section51_main_suite,
)
from src.timecourse_figures import (
    build_fig5_1_panel_tables,
    draw_fig5_1_combined_panel,
    draw_fig5_1_hidden_t2_panel,
    draw_fig5_1_seen_t4_panel,
    draw_fig5_1_time_pair_designs,
    draw_fig5_1_velocity_jump_panel,
    register_fig5_1_artifacts,
)
from src.timecourse_reporting import (
    audit_section51_main_text_results,
    display_png,
    json_ready,
    make_section51_config,
    preview_frame,
    verify_expected_display_values,
    write_section51_artifacts,
)

# %%
CONFIG = make_section51_config(PROJECT_ROOT)
FIG_DIR = CONFIG.fig_dir
TABLE_DIR = CONFIG.table_dir
OUTPUT_DIR = CONFIG.output_dir
DEFAULT_SEED = CONFIG.default_seed
SECTION51_MAIN_SUITE_SEEDS = CONFIG.suite_seeds
BATCH_SIZE = CONFIG.batch_size
NFE = CONFIG.nfe
EB_MAX_CELLS_PER_TIME = CONFIG.eb_max_cells_per_time
DEVICE = CONFIG.device

plt.rcParams.update({
    "figure.dpi": 120,
    "savefig.dpi": 220,
    "font.size": 9,
    "axes.titlesize": 10,
    "axes.labelsize": 9,
    "legend.fontsize": 8,
    "axes.spines.top": False,
    "axes.spines.right": False,
})

set_global_seed(DEFAULT_SEED)
print(f"Device: {DEVICE}; batch={BATCH_SIZE}; nfe={NFE}")
print(f"Seeds: {SECTION51_MAIN_SUITE_SEEDS}")
print(f"EB max cells per time: {EB_MAX_CELLS_PER_TIME}")
# Out:
# Device: cuda; batch=256; nfe=32
# Seeds: [42, 43, 44]
# EB max cells per time: 900

# %% [markdown]
# ## 3. Load EB data
#
# The loader standardizes the PC representation, keeps a balanced maximum number of cells per time point, and returns dictionaries keyed by the original time labels. We keep `t2` hidden for interpolation-style evaluation and use `t4` as a long-horizon endpoint check.

# %%
eb = load_eb_ch05(
    CONFIG.eb_path,
    max_cells_per_time=EB_MAX_CELLS_PER_TIME,
    seed=DEFAULT_SEED,
    n_pc=20,
)

by_time = eb["by_time"]
time_values = eb["time_values"]
print(f"EB path: {CONFIG.eb_path.relative_to(PROJECT_ROOT)}")
print("Time values:", time_values)
preview_frame(eb["counts"], n=10)
# Out:
# EB path: data/trajectorynet_eb/eb_velocity_v5.npz
# Time values: {'0': 0.0, '1': 0.25, '2': 0.5, '3': 0.75, '4': 1.0}
#   time  n_cells
# 0    0      900
# 1    1      900
# 2    2      900
# 3    3      900
# 4    4      900
#   time  n_cells
# 0    0      900
# 1    1      900
# 2    2      900
# 3    3      900
# 4    4      900

# %% [markdown]
# ## 4. Define pair topology and model variants
#
# The topology is the experimental design. Pairwise local bridges train one model per adjacent interval. Shared models train one global velocity field over several source-target pairs. Skip supervision adds longer pairs so the field sees nonlocal constraints, but the weighting controls whether skip pairs dominate the adjacent pairs.

# %%
adjacent_pairs = [("0", "1"), ("1", "3"), ("3", "4")]
skip_pairs = adjacent_pairs + [("0", "3"), ("1", "4"), ("0", "4")]

shared_specs = [
    {
        "variant": "shared_adjacent_only_6000",
        "variant_family": "shared_adjacent",
        "pairs": adjacent_pairs,
        "training_steps_total": 6000,
        "sampling": "uniform_adjacent",
        "pair_weights": None,
        "seed_offset": 30,
    },
    {
        "variant": "shared_skip_uniform_6000",
        "variant_family": "shared_skip",
        "pairs": skip_pairs,
        "training_steps_total": 6000,
        "sampling": "uniform_adjacent_skip",
        "pair_weights": None,
        "seed_offset": 40,
    },
    {
        "variant": "shared_skip_adj2_skip1_9000",
        "variant_family": "shared_skip",
        "pairs": skip_pairs,
        "training_steps_total": 9000,
        "sampling": "adjacent_total_2_3_skip_total_1_3",
        "pair_weights": [2.0, 2.0, 2.0, 1.0, 1.0, 1.0],
        "seed_offset": 50,
    },
]

print("Adjacent pairs:", adjacent_pairs)
print("Skip pairs:", skip_pairs)
# Out:
# Adjacent pairs: [('0', '1'), ('1', '3'), ('3', '4')]
# Skip pairs: [('0', '1'), ('1', '3'), ('3', '4'), ('0', '3'), ('1', '4'), ('0', '4')]

# %%
variant_table = pd.DataFrame([
    {
        "variant": "pairwise_local_bridges_6000",
        "family": "pairwise",
        "pairs": ";".join(f"{a}-{b}" for a, b in adjacent_pairs),
        "steps": 6000,
        "sampling": "local_pairwise",
    },
    *[
        {
            "variant": spec["variant"],
            "family": spec["variant_family"],
            "pairs": ";".join(f"{a}-{b}" for a, b in spec["pairs"]),
            "steps": spec["training_steps_total"],
            "sampling": spec["sampling"],
        }
        for spec in shared_specs
    ],
])
preview_frame(variant_table, n=10)
# Out:
#                        variant           family                    pairs  \
# 0  pairwise_local_bridges_6000         pairwise              0-1;1-3;3-4
# 1    shared_adjacent_only_6000  shared_adjacent              0-1;1-3;3-4
# 2     shared_skip_uniform_6000      shared_skip  0-1;1-3;3-4;0-3;1-4;0-4
# 3  shared_skip_adj2_skip1_9000      shared_skip  0-1;1-3;3-4;0-3;1-4;0-4
#
#    steps                           sampling
# 0   6000                     local_pairwise
# 1   6000                   uniform_adjacent
# 2   6000              uniform_adjacent_skip
# 3   9000  adjacent_total_2_3_skip_total_1_3
#                        variant           family                    pairs  \
# 0  pairwise_local_bridges_6000         pairwise              0-1;1-3;3-4
# 1    shared_adjacent_only_6000  shared_adjacent              0-1;1-3;3-4
# 2     shared_skip_uniform_6000      shared_skip  0-1;1-3;3-4;0-3;1-4;0-4
# 3  shared_skip_adj2_skip1_9000      shared_skip  0-1;1-3;3-4;0-3;1-4;0-4
#
#    steps                           sampling
# 0   6000                     local_pairwise
# 1   6000                   uniform_adjacent
# 2   6000              uniform_adjacent_skip
# 3   9000  adjacent_total_2_3_skip_total_1_3

# %% [markdown]
# ## 5. Train pairwise local bridges
#
# A pairwise baseline trains one independent bridge per adjacent interval. This is easy to interpret, but its velocity field is not globally shared, so rollouts must stitch local bridges together at hand-off times.

# %%
pair_steps = 6000 // len(adjacent_pairs)
pair_models_by_seed = {}
rng_state_after_pairwise_by_seed = {}
histories = {}

for run_seed in SECTION51_MAIN_SUITE_SEEDS:
    set_global_seed(DEFAULT_SEED)
    pair_models = {}
    for pair_idx, pair in enumerate(adjacent_pairs):
        model, hist = _train_local_bridge(
            by_time[pair[0]],
            by_time[pair[1]],
            pair_steps,
            BATCH_SIZE,
            int(run_seed) + 10 + pair_idx,
            device=DEVICE,
        )
        pair_models[pair] = model
        histories[(int(run_seed), f"pairwise_{pair[0]}_{pair[1]}")] = hist
    pair_models_by_seed[int(run_seed)] = pair_models
    rng_state_after_pairwise_by_seed[int(run_seed)] = {
        "cpu": torch.random.get_rng_state(),
        "cuda": torch.cuda.get_rng_state_all() if torch.cuda.is_available() else None,
    }

print(f"Trained {len(pair_models_by_seed) * len(adjacent_pairs)} local bridges")
print("Pairwise steps per local bridge:", pair_steps)
# Out:
# Trained 9 local bridges
# Pairwise steps per local bridge: 2000

# %% [markdown]
# ## 6. Train shared global bridges
#
# The shared models use one velocity field across multiple source-target pairs. The adjacent-only shared model tests whether global sharing helps recover a hidden intermediate snapshot. The skip variants test whether long-range pair supervision helps endpoint rollout.

# %%
shared_models_by_seed = {}

for run_seed in SECTION51_MAIN_SUITE_SEEDS:
    run_seed = int(run_seed)
    torch.random.set_rng_state(rng_state_after_pairwise_by_seed[run_seed]["cpu"])
    cuda_state = rng_state_after_pairwise_by_seed[run_seed]["cuda"]
    if cuda_state is not None and torch.cuda.is_available():
        torch.cuda.set_rng_state_all(cuda_state)

    shared_models = {}
    for spec in shared_specs:
        model, hist = _train_global_bridge_model(
            by_time,
            spec["pairs"],
            time_values,
            int(spec["training_steps_total"]),
            BATCH_SIZE,
            run_seed + int(spec["seed_offset"]),
            device=DEVICE,
            pair_weights=spec["pair_weights"],
        )
        shared_models[spec["variant"]] = model
        histories[(run_seed, spec["variant"])] = hist
    shared_models_by_seed[run_seed] = shared_models

print(f"Trained {len(shared_models_by_seed) * len(shared_specs)} shared models")
print("Stored history keys:", len(histories))
# Out:
# Trained 9 shared models
# Stored history keys: 18

# %% [markdown]
# ## 7. Roll out predictions
#
# Every variant starts from the observed `t0` population. We evaluate two endpoints: hidden `t2` at global time `0.50`, and seen `t4` at global time `1.00`. Pairwise rollouts stitch local bridges; shared rollouts integrate one global field.

# %%
X0 = by_time["0"]
targets = {"hidden_t2": by_time["2"], "seen_t4": by_time["4"]}
predictions_by_seed = {}
print("Evaluation targets:", sorted(targets.keys()))
# Out:
# Evaluation targets: ['hidden_t2', 'seen_t4']

# %%
for run_seed in SECTION51_MAIN_SUITE_SEEDS:
    run_seed = int(run_seed)
    pair_models = pair_models_by_seed[run_seed]
    predictions_by_seed[run_seed] = {
        "pairwise_local_bridges_6000": {
            "variant_family": "pairwise",
            "training_steps_total": int(pair_steps * len(adjacent_pairs)),
            "sampling": "local_pairwise",
            "pairs": adjacent_pairs,
            "pair_weights": "",
            "hidden_t2": _local_sequence_rollout(
                pair_models,
                X0,
                [(("0", "1"), 1.0), (("1", "3"), 0.5)],
                NFE,
                device=DEVICE,
            ),
            "seen_t4": _local_sequence_rollout(
                pair_models,
                X0,
                [(("0", "1"), 1.0), (("1", "3"), 1.0), (("3", "4"), 1.0)],
                NFE,
                device=DEVICE,
            ),
        }
    }

print("Pairwise predictions complete:", len(predictions_by_seed))
# Out:
# Pairwise predictions complete: 3

# %%
for run_seed in SECTION51_MAIN_SUITE_SEEDS:
    run_seed = int(run_seed)
    for spec in shared_specs:
        model = shared_models_by_seed[run_seed][spec["variant"]]
        weights = spec["pair_weights"]
        pair_weights = "uniform" if weights is None else ",".join(
            f"{w:.6g}" for w in (np.asarray(weights, dtype=float) / np.sum(weights))
        )
        predictions_by_seed[run_seed][spec["variant"]] = {
            "variant_family": spec["variant_family"],
            "training_steps_total": int(spec["training_steps_total"]),
            "sampling": spec["sampling"],
            "pairs": spec["pairs"],
            "pair_weights": pair_weights,
            "hidden_t2": _global_rollout(model, X0, 0.5, NFE * 2, device=DEVICE),
            "seen_t4": _global_rollout(model, X0, 1.0, NFE * 4, device=DEVICE),
        }

print("Prediction variants:", sorted(next(iter(predictions_by_seed.values())).keys()))
# Out:
# Prediction variants: ['pairwise_local_bridges_6000', 'shared_adjacent_only_6000', 'shared_skip_adj2_skip1_9000', 'shared_skip_uniform_6000']

# %% [markdown]
# ## 8. Compute endpoint metrics
#
# The endpoint table is one row per seed, variant, and target. Lower MMD, sliced Wasserstein, and centroid distance all indicate closer agreement between a rollout population and the held-out or endpoint snapshot.

# %%
rows = []
for run_seed, predictions in predictions_by_seed.items():
    for variant, payload in predictions.items():
        for target_name in ["hidden_t2", "seen_t4"]:
            metrics = endpoint_distribution_metrics(payload[target_name], targets[target_name])
            rows.append(
                {
                    "experiment": "EB Section 5.1 main suite",
                    "seed": int(run_seed),
                    "variant": variant,
                    "variant_family": payload["variant_family"],
                    "target": target_name,
                    "training_steps_total": int(payload["training_steps_total"]),
                    "sampling": payload["sampling"],
                    "pairs": ";".join(f"{a}-{b}" for a, b in payload["pairs"]),
                    "pair_weights": payload["pair_weights"],
                    "mmd_rbf": float(metrics["mmd_rbf"]),
                    "sliced_w2": float(metrics["sliced_w2"]),
                    "centroid_l2": float(metrics["centroid_l2"]),
                }
            )

section51_metrics = pd.DataFrame(rows)
print("Metrics shape:", section51_metrics.shape)
preview_frame(
    section51_metrics,
    columns=["seed", "variant", "target", "mmd_rbf", "sliced_w2", "centroid_l2"],
    n=8,
)
# Out:
# Metrics shape: (24, 12)
#    seed                      variant     target   mmd_rbf  sliced_w2  \
# 0    42  pairwise_local_bridges_6000  hidden_t2  0.080739   0.402712
# 1    42  pairwise_local_bridges_6000    seen_t4  0.007199   0.214815
# 2    42    shared_adjacent_only_6000  hidden_t2  0.059406   0.376872
# 3    42    shared_adjacent_only_6000    seen_t4  0.008241   0.188741
# 4    42     shared_skip_uniform_6000  hidden_t2  0.066241   0.383317
# 5    42     shared_skip_uniform_6000    seen_t4  0.007472   0.205588
# 6    42  shared_skip_adj2_skip1_9000  hidden_t2  0.063294   0.379612
# 7    42  shared_skip_adj2_skip1_9000    seen_t4  0.008891   0.240142
#
#    centroid_l2
# 0     1.115312
# 1     0.678975
# 2     1.157762
# 3     0.571825
# 4     1.223948
# 5     0.663954
# 6     1.318759
# 7     0.767860
#    seed                      variant     target   mmd_rbf  sliced_w2  \
# 0    42  pairwise_local_bridges_6000  hidden_t2  0.080739   0.402712
# 1    42  pairwise_local_bridges_6000    seen_t4  0.007199   0.214815
# 2    42    shared_adjacent_only_6000  hidden_t2  0.059406   0.376872
# 3    42    shared_adjacent_only_6000    seen_t4  0.008241   0.188741
# 4    42     shared_skip_uniform_6000  hidden_t2  0.066241   0.383317
# 5    42     shared_skip_uniform_6000    seen_t4  0.007472   0.205588
# 6    42  shared_skip_adj2_skip1_9000  hidden_t2  0.063294   0.379612
# 7    42  shared_skip_adj2_skip1_9000    seen_t4  0.008891   0.240142
#
#    centroid_l2
# 0     1.115312
# 1     0.678975
# 2     1.157762
# 3     0.571825
# 4     1.223948
# 5     0.663954
# 6     1.318759
# 7     0.767860

# %% [markdown]
# ## 9. Compute hand-off diagnostics
#
# Endpoint scores do not tell us whether the learned velocity field is smooth at the observed hand-off points. The diagnostic below compares the velocity just before and after `t1` and `t3`. Pairwise local bridges can jump because the left and right sides are different models.

# %%
diag_rows = []
boundary_specs = [("t1", "1", 0.25), ("t3", "3", 0.75)]
device_obj = torch.device(DEVICE)

for run_seed in SECTION51_MAIN_SUITE_SEEDS:
    run_seed = int(run_seed)
    pair_models = pair_models_by_seed[run_seed]
    shared_models = shared_models_by_seed[run_seed]
    for boundary, boundary_time, t_global in boundary_specs:
        Xb = by_time[boundary_time]
        xb = torch.as_tensor(Xb, dtype=torch.float32, device=device_obj)
        left_pair = ("0", "1") if boundary == "t1" else ("1", "3")
        right_pair = ("1", "3") if boundary == "t1" else ("3", "4")
        with torch.no_grad():
            v_left = pair_models[left_pair](
                xb,
                torch.ones((len(Xb), 1), device=device_obj),
            ).detach().cpu().numpy()
            v_right = pair_models[right_pair](
                xb,
                torch.zeros((len(Xb), 1), device=device_obj),
            ).detach().cpu().numpy()
        diag_rows.append(
            {
                "experiment": "EB Section 5.1 main suite",
                "seed": int(run_seed),
                "variant": "pairwise_local_bridges_6000",
                "variant_family": "pairwise",
                "boundary": boundary,
                "training_steps_total": int(pair_steps * len(adjacent_pairs)),
                "sampling": "local_pairwise",
                "velocity_jump_mean_l2": float(np.linalg.norm(v_left - v_right, axis=1).mean()),
            }
        )
        for spec in shared_specs:
            model = shared_models[spec["variant"]]
            with torch.no_grad():
                t_left = torch.full((len(Xb), 1), max(0.0, t_global - 0.01), device=device_obj)
                t_right = torch.full((len(Xb), 1), min(1.0, t_global + 0.01), device=device_obj)
                vl = model(xb, t_left).detach().cpu().numpy()
                vr = model(xb, t_right).detach().cpu().numpy()
            diag_rows.append(
                {
                    "experiment": "EB Section 5.1 main suite",
                    "seed": int(run_seed),
                    "variant": spec["variant"],
                    "variant_family": spec["variant_family"],
                    "boundary": boundary,
                    "training_steps_total": int(spec["training_steps_total"]),
                    "sampling": spec["sampling"],
                    "velocity_jump_mean_l2": float(np.linalg.norm(vl - vr, axis=1).mean()),
                }
            )

section51_diag = pd.DataFrame(diag_rows)
print("Diagnostics shape:", section51_diag.shape)
preview_frame(section51_diag, columns=["seed", "variant", "boundary", "velocity_jump_mean_l2"], n=8)
# Out:
# Diagnostics shape: (24, 8)
#    seed                      variant boundary  velocity_jump_mean_l2
# 0    42  pairwise_local_bridges_6000       t1               8.053829
# 1    42    shared_adjacent_only_6000       t1               8.168670
# 2    42     shared_skip_uniform_6000       t1               5.628532
# 3    42  shared_skip_adj2_skip1_9000       t1               8.994890
# 4    42  pairwise_local_bridges_6000       t3               8.590636
# 5    42    shared_adjacent_only_6000       t3               4.799015
# 6    42     shared_skip_uniform_6000       t3               2.404038
# 7    42  shared_skip_adj2_skip1_9000       t3               4.212292
#    seed                      variant boundary  velocity_jump_mean_l2
# 0    42  pairwise_local_bridges_6000       t1               8.053829
# 1    42    shared_adjacent_only_6000       t1               8.168670
# 2    42     shared_skip_uniform_6000       t1               5.628532
# 3    42  shared_skip_adj2_skip1_9000       t1               8.994890
# 4    42  pairwise_local_bridges_6000       t3               8.590636
# 5    42    shared_adjacent_only_6000       t3               4.799015
# 6    42     shared_skip_uniform_6000       t3               2.404038
# 7    42  shared_skip_adj2_skip1_9000       t3               4.212292

# %% [markdown]
# ## 10. Summarize metrics into paper-facing tables
#
# The raw tables keep seed-level rows. The summary tables average over seeds, and `build_ch05_section51_main_text_results` extracts only the values used by the paper text and claim audit.

# %%
section51_summary, section51_diag_summary = summarize_eb_section51_main_suite(
    section51_metrics,
    section51_diag,
)
section51_main_text_results, section51_summary_payload = build_ch05_section51_main_text_results(
    section51_summary,
    section51_diag_summary,
)

print("Summary shape:", section51_summary.shape)
print("Diagnostic summary shape:", section51_diag_summary.shape)
print("Main-text result shape:", section51_main_text_results.shape)
preview_frame(
    section51_summary,
    columns=["variant", "target", "mmd_rbf_mean", "sliced_w2_mean", "centroid_l2_mean", "n_seeds"],
    n=8,
)
# Out:
# Summary shape: (8, 12)
# Diagnostic summary shape: (8, 8)
# Main-text result shape: (28, 12)
#                        variant     target  mmd_rbf_mean  sliced_w2_mean  \
# 0  pairwise_local_bridges_6000  hidden_t2      0.083634        0.408452
# 1    shared_adjacent_only_6000  hidden_t2      0.056502        0.355996
# 2  shared_skip_adj2_skip1_9000  hidden_t2      0.067479        0.384300
# 3     shared_skip_uniform_6000  hidden_t2      0.060557        0.376329
# 4  pairwise_local_bridges_6000    seen_t4      0.006871        0.172061
# 5    shared_adjacent_only_6000    seen_t4      0.014107        0.321605
# 6  shared_skip_adj2_skip1_9000    seen_t4      0.008896        0.214999
# 7     shared_skip_uniform_6000    seen_t4      0.009422        0.237947
#
#    centroid_l2_mean  n_seeds
# 0          1.127930        3
# 1          1.139057        3
# 2          1.221085        3
# 3          1.213556        3
# 4          0.582460        3
# 5          0.904182        3
# 6          0.663832        3
# 7          0.726386        3
#                        variant     target  mmd_rbf_mean  sliced_w2_mean  \
# 0  pairwise_local_bridges_6000  hidden_t2      0.083634        0.408452
# 1    shared_adjacent_only_6000  hidden_t2      0.056502        0.355996
# 2  shared_skip_adj2_skip1_9000  hidden_t2      0.067479        0.384300
# 3     shared_skip_uniform_6000  hidden_t2      0.060557        0.376329
# 4  pairwise_local_bridges_6000    seen_t4      0.006871        0.172061
# 5    shared_adjacent_only_6000    seen_t4      0.014107        0.321605
# 6  shared_skip_adj2_skip1_9000    seen_t4      0.008896        0.214999
# 7     shared_skip_uniform_6000    seen_t4      0.009422        0.237947
#
#    centroid_l2_mean  n_seeds
# 0          1.127930        3
# 1          1.139057        3
# 2          1.221085        3
# 3          1.213556        3
# 4          0.582460        3
# 5          0.904182        3
# 6          0.663832        3
# 7          0.726386        3

# %% [markdown]
# ## 11. Save official artifacts
#
# This cell writes the same official files as the original notebook. The reusable helper handles CSV/JSON saving, Figure 5.1 construction, and `run_summary.json` updates; the experiment objects being saved were built above in the notebook.

# %%
artifact_paths = write_section51_artifacts(
    section51_metrics,
    section51_diag,
    section51_summary,
    section51_diag_summary,
    section51_main_text_results,
    section51_summary_payload,
    CONFIG,
)

for name, path in artifact_paths.items():
    print(f"{name}: {path.relative_to(PROJECT_ROOT)}")

figure_path = artifact_paths["figure"]
main_text_path = artifact_paths["main_text"]
run_summary_path = artifact_paths["run_summary"]
display_png(figure_path)
# Out:
# metrics: tables/ch05/tab_5_1_main_suite.csv
# summary: tables/ch05/tab_5_1_main_suite_summary.csv
# diagnostics: tables/ch05/tab_5_1_main_suite_diag.csv
# diagnostic_summary: tables/ch05/tab_5_1_main_suite_diag_summary.csv
# main_text: tables/ch05/tab_5_1_main_text_results.csv
# figure: figures/ch05/fig_5_1_main_suite.png
# run_summary: outputs/ch05/run_summary.json
# PosixPath('/import/macyang_home4/xmabs/flow_matching_for_dynamic_biology/flow_matching_for_dynamic_biology/figures/ch05/fig_5_1_main_suite.png')

# %% [markdown]
# ## 12. Redraw Figure 5.1 as independent paper panels
#
# The cells below redraw the Section 5.1 main figure as independent publication panels. Each panel is generated, displayed, and saved in its own code cell. The quantitative panels use seed-level tables from this notebook and show mean ± SEM across seeds; no values are hand-entered in the plotting code.

# %%
# Use in-memory tables when the notebook has just generated them; fall back to saved tables for reruns from this section.
if "section51_metrics" not in globals():
    section51_metrics = pd.read_csv(TABLE_DIR / "tab_5_1_main_suite.csv")
if "section51_diag" not in globals():
    section51_diag = pd.read_csv(TABLE_DIR / "tab_5_1_main_suite_diag.csv")

fig5_1_tables = build_fig5_1_panel_tables(section51_metrics, section51_diag)
fig5_1_hidden_t2_values = fig5_1_tables.hidden_t2_values
fig5_1_seen_t4_values = fig5_1_tables.seen_t4_values
fig5_1_velocity_jump_values = fig5_1_tables.velocity_jump_values
fig5_1_panel_sources = fig5_1_tables.panel_sources
fig5_1_missing_entries = fig5_1_tables.missing_entries

print("Figure 5.1 three-method redraw setup ready")
print("Error bars: mean +/- SEM across seed-level rows; n=3 for all quantitative panels")
preview_frame(fig5_1_panel_sources, n=len(fig5_1_panel_sources))
# Out:
# Figure 5.1 three-method redraw setup ready
# Error bars: mean +/- SEM across seed-level rows; n=3 for all quantitative panels
#                         panel             source_dataframe  \
# 0  Training time-pair designs              panel schematic
# 1         Hidden t=2 recovery      fig5_1_hidden_t2_values
# 2            Seen t=4 rollout        fig5_1_seen_t4_values
# 3  Velocity jump at hand-offs  fig5_1_velocity_jump_values
#
#                                         source_table
# 0  adjacent_pairs and skip_pairs defined in this ...
# 1         tab_5_1_main_suite.csv / section51_metrics
# 2         tab_5_1_main_suite.csv / section51_metrics
# 3       tab_5_1_main_suite_diag.csv / section51_diag
#                         panel             source_dataframe  \
# 0  Training time-pair designs              panel schematic
# 1         Hidden t=2 recovery      fig5_1_hidden_t2_values
# 2            Seen t=4 rollout        fig5_1_seen_t4_values
# 3  Velocity jump at hand-offs  fig5_1_velocity_jump_values
#
#                                         source_table
# 0  adjacent_pairs and skip_pairs defined in this ...
# 1         tab_5_1_main_suite.csv / section51_metrics
# 2         tab_5_1_main_suite.csv / section51_metrics
# 3       tab_5_1_main_suite_diag.csv / section51_diag

# %%
fig5_1_paths = {}
fig5_1_paths.update(
    draw_fig5_1_time_pair_designs(
        adjacent_pairs=adjacent_pairs,
        skip_pairs=skip_pairs,
        fig_dir=FIG_DIR,
        display_fn=display_png,
    )
)

print("Generated time-pair design panel")
# Out:
# Generated time-pair design panel

# %%
fig5_1_paths.update(
    draw_fig5_1_hidden_t2_panel(
        fig5_1_hidden_t2_values,
        fig_dir=FIG_DIR,
        display_fn=display_png,
    )
)

print("Hidden t=2 recovery values")
preview_frame(
    fig5_1_hidden_t2_values[["method", "target", "metric", "mean", "sem", "sd", "n_seeds", "source_table", "error_bar"]],
    n=len(fig5_1_hidden_t2_values),
)
# Out:
# Hidden t=2 recovery values
#                        method     target     metric      mean       sem  \
# 0       Pairwise local bridge  hidden_t2    mmd_rbf  0.083634  0.001452
# 1       Pairwise local bridge  hidden_t2  sliced_w2  0.408452  0.004814
# 2  Shared adjacent-only field  hidden_t2    mmd_rbf  0.056502  0.003483
# 3  Shared adjacent-only field  hidden_t2  sliced_w2  0.355996  0.013849
# 4  Shared adjacent+skip field  hidden_t2    mmd_rbf  0.067479  0.005572
# 5  Shared adjacent+skip field  hidden_t2  sliced_w2  0.384300  0.008058
#
#          sd  n_seeds            source_table         error_bar
# 0  0.002516        3  tab_5_1_main_suite.csv  SEM across seeds
# 1  0.008338        3  tab_5_1_main_suite.csv  SEM across seeds
# 2  0.006033        3  tab_5_1_main_suite.csv  SEM across seeds
# 3  0.023987        3  tab_5_1_main_suite.csv  SEM across seeds
# 4  0.009651        3  tab_5_1_main_suite.csv  SEM across seeds
# 5  0.013958        3  tab_5_1_main_suite.csv  SEM across seeds
#                        method     target     metric      mean       sem  \
# 0       Pairwise local bridge  hidden_t2    mmd_rbf  0.083634  0.001452
# 1       Pairwise local bridge  hidden_t2  sliced_w2  0.408452  0.004814
# 2  Shared adjacent-only field  hidden_t2    mmd_rbf  0.056502  0.003483
# 3  Shared adjacent-only field  hidden_t2  sliced_w2  0.355996  0.013849
# 4  Shared adjacent+skip field  hidden_t2    mmd_rbf  0.067479  0.005572
# 5  Shared adjacent+skip field  hidden_t2  sliced_w2  0.384300  0.008058
#
#          sd  n_seeds            source_table         error_bar
# 0  0.002516        3  tab_5_1_main_suite.csv  SEM across seeds
# 1  0.008338        3  tab_5_1_main_suite.csv  SEM across seeds
# 2  0.006033        3  tab_5_1_main_suite.csv  SEM across seeds
# 3  0.023987        3  tab_5_1_main_suite.csv  SEM across seeds
# 4  0.009651        3  tab_5_1_main_suite.csv  SEM across seeds
# 5  0.013958        3  tab_5_1_main_suite.csv  SEM across seeds

# %%
fig5_1_paths.update(
    draw_fig5_1_seen_t4_panel(
        fig5_1_seen_t4_values,
        fig_dir=FIG_DIR,
        display_fn=display_png,
    )
)

print("Seen t=4 rollout values")
preview_frame(
    fig5_1_seen_t4_values[["method", "target", "metric", "mean", "sem", "sd", "n_seeds", "source_table", "error_bar"]],
    n=len(fig5_1_seen_t4_values),
)
# Out:
# Seen t=4 rollout values
#                        method   target       metric      mean       sem  \
# 0       Pairwise local bridge  seen_t4    sliced_w2  0.172061  0.021686
# 1       Pairwise local bridge  seen_t4  centroid_l2  0.582460  0.067813
# 2  Shared adjacent-only field  seen_t4    sliced_w2  0.321605  0.080824
# 3  Shared adjacent-only field  seen_t4  centroid_l2  0.904182  0.190381
# 4  Shared adjacent+skip field  seen_t4    sliced_w2  0.214999  0.022097
# 5  Shared adjacent+skip field  seen_t4  centroid_l2  0.663832  0.112625
#
#          sd  n_seeds            source_table         error_bar
# 0  0.037561        3  tab_5_1_main_suite.csv  SEM across seeds
# 1  0.117455        3  tab_5_1_main_suite.csv  SEM across seeds
# 2  0.139992        3  tab_5_1_main_suite.csv  SEM across seeds
# 3  0.329750        3  tab_5_1_main_suite.csv  SEM across seeds
# 4  0.038274        3  tab_5_1_main_suite.csv  SEM across seeds
# 5  0.195072        3  tab_5_1_main_suite.csv  SEM across seeds
#                        method   target       metric      mean       sem  \
# 0       Pairwise local bridge  seen_t4    sliced_w2  0.172061  0.021686
# 1       Pairwise local bridge  seen_t4  centroid_l2  0.582460  0.067813
# 2  Shared adjacent-only field  seen_t4    sliced_w2  0.321605  0.080824
# 3  Shared adjacent-only field  seen_t4  centroid_l2  0.904182  0.190381
# 4  Shared adjacent+skip field  seen_t4    sliced_w2  0.214999  0.022097
# 5  Shared adjacent+skip field  seen_t4  centroid_l2  0.663832  0.112625
#
#          sd  n_seeds            source_table         error_bar
# 0  0.037561        3  tab_5_1_main_suite.csv  SEM across seeds
# 1  0.117455        3  tab_5_1_main_suite.csv  SEM across seeds
# 2  0.139992        3  tab_5_1_main_suite.csv  SEM across seeds
# 3  0.329750        3  tab_5_1_main_suite.csv  SEM across seeds
# 4  0.038274        3  tab_5_1_main_suite.csv  SEM across seeds
# 5  0.195072        3  tab_5_1_main_suite.csv  SEM across seeds

# %%
fig5_1_paths.update(
    draw_fig5_1_velocity_jump_panel(
        fig5_1_velocity_jump_values,
        fig_dir=FIG_DIR,
        display_fn=display_png,
    )
)

print("Velocity jump values")
preview_frame(
    fig5_1_velocity_jump_values[["method", "boundary", "metric", "mean", "sem", "sd", "n_seeds", "source_table", "error_bar"]],
    n=len(fig5_1_velocity_jump_values),
)
# Out:
# Velocity jump values
#                        method boundary                 metric      mean  \
# 0       Pairwise local bridge       t1  velocity_jump_mean_l2  8.032818
# 1  Shared adjacent-only field       t1  velocity_jump_mean_l2  8.135409
# 2  Shared adjacent+skip field       t1  velocity_jump_mean_l2  9.122618
# 3       Pairwise local bridge       t3  velocity_jump_mean_l2  8.657238
# 4  Shared adjacent-only field       t3  velocity_jump_mean_l2  4.805779
# 5  Shared adjacent+skip field       t3  velocity_jump_mean_l2  4.451229
#
#         sem        sd  n_seeds                 source_table         error_bar
# 0  0.014671  0.025411        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 1  0.026908  0.046606        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 2  0.068071  0.117903        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 3  0.055341  0.095853        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 4  0.009419  0.016314        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 5  0.125653  0.217638        3  tab_5_1_main_suite_diag.csv  SEM across seeds
#                        method boundary                 metric      mean  \
# 0       Pairwise local bridge       t1  velocity_jump_mean_l2  8.032818
# 1  Shared adjacent-only field       t1  velocity_jump_mean_l2  8.135409
# 2  Shared adjacent+skip field       t1  velocity_jump_mean_l2  9.122618
# 3       Pairwise local bridge       t3  velocity_jump_mean_l2  8.657238
# 4  Shared adjacent-only field       t3  velocity_jump_mean_l2  4.805779
# 5  Shared adjacent+skip field       t3  velocity_jump_mean_l2  4.451229
#
#         sem        sd  n_seeds                 source_table         error_bar
# 0  0.014671  0.025411        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 1  0.026908  0.046606        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 2  0.068071  0.117903        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 3  0.055341  0.095853        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 4  0.009419  0.016314        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 5  0.125653  0.217638        3  tab_5_1_main_suite_diag.csv  SEM across seeds

# %%
fig5_1_paths.update(
    draw_fig5_1_combined_panel(
        fig5_1_paths,
        fig_dir=FIG_DIR,
        display_fn=display_png,
    )
)

fig5_1_path_table = register_fig5_1_artifacts(
    fig5_1_paths,
    panel_sources=fig5_1_panel_sources,
    missing_entries=fig5_1_missing_entries,
    run_summary_path=run_summary_path,
    project_root=PROJECT_ROOT,
)
artifact_paths.update(fig5_1_paths)

print("Figure 5.1 redrawn panel files")
preview_frame(fig5_1_path_table, n=len(fig5_1_path_table))
print("Missing methods or metrics:", "none" if not fig5_1_missing_entries else fig5_1_missing_entries)
# Out:
# Figure 5.1 redrawn panel files
#                         artifact                               relative_path  \
# 9            fig5_1_combined_pdf            figures/ch05/fig5_1_combined.pdf
# 8            fig5_1_combined_png            figures/ch05/fig5_1_combined.png
# 3  fig5_1_hidden_t2_recovery_pdf  figures/ch05/fig5_1_hidden_t2_recovery.pdf
# 2  fig5_1_hidden_t2_recovery_png  figures/ch05/fig5_1_hidden_t2_recovery.png
# 5     fig5_1_seen_t4_rollout_pdf     figures/ch05/fig5_1_seen_t4_rollout.pdf
# 4     fig5_1_seen_t4_rollout_png     figures/ch05/fig5_1_seen_t4_rollout.png
# 1   fig5_1_time_pair_designs_pdf   figures/ch05/fig5_1_time_pair_designs.pdf
# 0   fig5_1_time_pair_designs_png   figures/ch05/fig5_1_time_pair_designs.png
# 7       fig5_1_velocity_jump_pdf       figures/ch05/fig5_1_velocity_jump.pdf
# 6       fig5_1_velocity_jump_png       figures/ch05/fig5_1_velocity_jump.png
#
#                                        absolute_path
# 9  /import/macyang_home4/xmabs/flow_matching_for_...
# 8  /import/macyang_home4/xmabs/flow_matching_for_...
# 3  /import/macyang_home4/xmabs/flow_matching_for_...
# 2  /import/macyang_home4/xmabs/flow_matching_for_...
# 5  /import/macyang_home4/xmabs/flow_matching_for_...
# 4  /import/macyang_home4/xmabs/flow_matching_for_...
# 1  /import/macyang_home4/xmabs/flow_matching_for_...
# 0  /import/macyang_home4/xmabs/flow_matching_for_...
# 7  /import/macyang_home4/xmabs/flow_matching_for_...
# 6  /import/macyang_home4/xmabs/flow_matching_for_...
# Missing methods or metrics: none

# %% [markdown]
# ## 13. Inspect the run summary
#
# The run summary records the paper-facing claim boundary and all official artifact paths. This makes the notebook output auditable after execution.

# %%
run_summary = json.loads(run_summary_path.read_text())
section_summary = run_summary["section_5_1_main_suite"]
print("Claim boundary:")
print(section_summary["claim_boundary"])
print()
print("Official artifact keys:")
print(json.dumps({k: v for k, v in section_summary.items() if k.endswith("table") or k == "figure"}, indent=2))
# Out:
# Claim boundary:
# shared field improves hidden-time recovery; weighted skip supervision improves seen endpoint long-horizon rollout but may degrade hidden-time recovery, so skip is a long-horizon endpoint constraint rather than a uniformly better dynamics model.
#
# Official artifact keys:
# {
#   "diag_summary_table": "tables/ch05/tab_5_1_main_suite_diag_summary.csv",
#   "diag_table": "tables/ch05/tab_5_1_main_suite_diag.csv",
#   "figure": "figures/ch05/fig_5_1_main_suite.png",
#   "main_text_results_table": "tables/ch05/tab_5_1_main_text_results.csv",
#   "metrics_table": "tables/ch05/tab_5_1_main_suite.csv",
#   "summary_table": "tables/ch05/tab_5_1_main_suite_summary.csv"
# }

# %% [markdown]
# ## 14. Final audit
#
# The audit checks that the main-text table has the expected claim parts, excludes cluster-mass side metrics, includes all hand-off rows, preserves exact display values, and that each official artifact exists. This is intentionally last: readers first see the experiment, then see how the paper-facing claims are guarded.

# %%
audit = pd.read_csv(main_text_path)
preview_frame(
    audit,
    columns=["claim_part", "method_or_variant", "target_or_boundary", "metric", "display_value"],
    n=28,
)

notebook_source = (PROJECT_ROOT / "notebooks" / "05_1_single_cell_timecourse_main_suite.ipynb").read_text()
audit_section51_main_text_results(audit, notebook_source=notebook_source)
verified_values = verify_expected_display_values(audit)

for path in artifact_paths.values():
    assert path.exists(), path

print("Main-text audit passed")
print("Expected display values verified:", verified_values)
print("Official artifacts verified:", len(artifact_paths))
print(json.dumps(json_ready({k: str(v.relative_to(PROJECT_ROOT)) for k, v in artifact_paths.items()}), indent=2))
# Out:
#                    claim_part  \
# 0   hidden_t2_main_comparison
# 1   hidden_t2_main_comparison
# 2   hidden_t2_main_comparison
# 3   hidden_t2_main_comparison
# 4   hidden_t2_main_comparison
# 5   hidden_t2_main_comparison
# 6        seen_t4_long_horizon
# 7        seen_t4_long_horizon
# 8        seen_t4_long_horizon
# 9        seen_t4_long_horizon
# 10       seen_t4_long_horizon
# 11       seen_t4_long_horizon
# 12    hidden_t2_skip_tradeoff
# 13    hidden_t2_skip_tradeoff
# 14    hidden_t2_skip_tradeoff
# 15    hidden_t2_skip_tradeoff
# 16   velocity_jump_diagnostic
# 17   velocity_jump_diagnostic
# 18   velocity_jump_diagnostic
# 19   velocity_jump_diagnostic
# 20   velocity_jump_diagnostic
# 21   velocity_jump_diagnostic
# 22   velocity_jump_diagnostic
# 23   velocity_jump_diagnostic
# 24   velocity_jump_diagnostic
# 25   velocity_jump_diagnostic
# 26   velocity_jump_diagnostic
# 27   velocity_jump_diagnostic
#
#                                   method_or_variant target_or_boundary  \
# 0                       pairwise_local_bridges_6000          hidden_t2
# 1                       pairwise_local_bridges_6000          hidden_t2
# 2                         shared_adjacent_only_6000          hidden_t2
# 3                         shared_adjacent_only_6000          hidden_t2
# 4                       shared_skip_adj2_skip1_9000          hidden_t2
# 5                       shared_skip_adj2_skip1_9000          hidden_t2
# 6                         shared_adjacent_only_6000            seen_t4
# 7                         shared_adjacent_only_6000            seen_t4
# 8                       shared_skip_adj2_skip1_9000            seen_t4
# 9                       shared_skip_adj2_skip1_9000            seen_t4
# 10  relative_improvement_skip_2to1_vs_adjacent_only            seen_t4
# 11  relative_improvement_skip_2to1_vs_adjacent_only            seen_t4
# 12                        shared_adjacent_only_6000          hidden_t2
# 13                        shared_adjacent_only_6000          hidden_t2
# 14                      shared_skip_adj2_skip1_9000          hidden_t2
# 15                      shared_skip_adj2_skip1_9000          hidden_t2
# 16                      pairwise_local_bridges_6000                 t1
# 17                      pairwise_local_bridges_6000                 t3
# 18                      pairwise_local_bridges_6000         t1_t3_mean
# 19                        shared_adjacent_only_6000                 t1
# 20                        shared_adjacent_only_6000                 t3
# 21                        shared_adjacent_only_6000         t1_t3_mean
# 22                      shared_skip_adj2_skip1_9000                 t1
# 23                      shared_skip_adj2_skip1_9000                 t3
# 24                      shared_skip_adj2_skip1_9000         t1_t3_mean
# 25                         shared_skip_uniform_6000                 t1
# 26                         shared_skip_uniform_6000                 t3
# 27                         shared_skip_uniform_6000         t1_t3_mean
#
#                                        metric display_value
# 0                                     mmd_rbf        0.0836
# 1                                   sliced_w2         0.408
# 2                                     mmd_rbf        0.0565
# 3                                   sliced_w2         0.356
# 4                                     mmd_rbf        0.0675
# 5                                   sliced_w2         0.384
# 6                                   sliced_w2         0.322
# 7                                 centroid_l2         0.904
# 8                                   sliced_w2         0.215
# 9                                 centroid_l2         0.664
# 10                        sliced_w2_pct_lower   33.1% lower
# 11                      centroid_l2_pct_lower   26.6% lower
# 12                                    mmd_rbf        0.0565
# 13                                  sliced_w2         0.356
# 14                                    mmd_rbf        0.0675
# 15                                  sliced_w2         0.384
# 16                      velocity_jump_mean_l2          8.03
# 17                      velocity_jump_mean_l2          8.66
# 18  velocity_jump_mean_l2_mean_over_hand_offs          8.35
# 19                      velocity_jump_mean_l2          8.14
# 20                      velocity_jump_mean_l2          4.81
# 21  velocity_jump_mean_l2_mean_over_hand_offs          6.47
# 22                      velocity_jump_mean_l2          9.12
# 23                      velocity_jump_mean_l2          4.45
# 24  velocity_jump_mean_l2_mean_over_hand_offs          6.79
# 25                      velocity_jump_mean_l2          5.79
# 26                      velocity_jump_mean_l2          2.26
# 27  velocity_jump_mean_l2_mean_over_hand_offs          4.03
# Main-text audit passed
# Expected display values verified: 24
# Official artifacts verified: 17
# {
#   "metrics": "tables/ch05/tab_5_1_main_suite.csv",
#   "summary": "tables/ch05/tab_5_1_main_suite_summary.csv",
#   "diagnostics": "tables/ch05/tab_5_1_main_suite_diag.csv",
#   "diagnostic_summary": "tables/ch05/tab_5_1_main_suite_diag_summary.csv",
#   "main_text": "tables/ch05/tab_5_1_main_text_results.csv",
#   "figure": "figures/ch05/fig_5_1_main_suite.png",
#   "run_summary": "outputs/ch05/run_summary.json",
#   "fig5_1_time_pair_designs_png": "figures/ch05/fig5_1_time_pair_designs.png",
#   "fig5_1_time_pair_designs_pdf": "figures/ch05/fig5_1_time_pair_designs.pdf",
#   "fig5_1_hidden_t2_recovery_png": "figures/ch05/fig5_1_hidden_t2_recovery.png",
#   "fig5_1_hidden_t2_recovery_pdf": "figures/ch05/fig5_1_hidden_t2_recovery.pdf",
#   "fig5_1_seen_t4_rollout_png": "figures/ch05/fig5_1_seen_t4_rollout.png",
#   "fig5_1_seen_t4_rollout_pdf": "figures/ch05/fig5_1_seen_t4_rollout.pdf",
#   "fig5_1_velocity_jump_png": "figures/ch05/fig5_1_velocity_jump.png",
#   "fig5_1_velocity_jump_pdf": "figures/ch05/fig5_1_velocity_jump.pdf",
#   "fig5_1_combined_png": "figures/ch05/fig5_1_combined.png",
#   "fig5_1_combined_pdf": "figures/ch05/fig5_1_combined.pdf"
# }

# %% [markdown]
# ## 16. Figure 5.1 redrawn panel summary
#
# This summary records the independent files generated by the redrawn Figure 5.1 cells, the source tables behind each panel, and the numeric values used in the quantitative panels.

# %%
print("Figure 5.1 redrawn panel files")
preview_frame(fig5_1_path_table, n=len(fig5_1_path_table))

print("Panel data sources")
preview_frame(fig5_1_panel_sources, n=len(fig5_1_panel_sources))

print("Hidden t=2 recovery values")
preview_frame(
    fig5_1_hidden_t2_values[["method", "target", "metric", "mean", "sem", "sd", "n_seeds", "source_table", "error_bar"]],
    n=len(fig5_1_hidden_t2_values),
)

print("Seen t=4 rollout values")
preview_frame(
    fig5_1_seen_t4_values[["method", "target", "metric", "mean", "sem", "sd", "n_seeds", "source_table", "error_bar"]],
    n=len(fig5_1_seen_t4_values),
)

print("Velocity jump values")
preview_frame(
    fig5_1_velocity_jump_values[["method", "boundary", "metric", "mean", "sem", "sd", "n_seeds", "source_table", "error_bar"]],
    n=len(fig5_1_velocity_jump_values),
)

combined_png = fig5_1_paths["fig5_1_combined_png"]
print("Missing methods or metrics:", "none" if not fig5_1_missing_entries else fig5_1_missing_entries)
print("Combined figure generated:", str(combined_png.relative_to(PROJECT_ROOT)))
# Out:
# Figure 5.1 redrawn panel files
#                         artifact                               relative_path  \
# 9            fig5_1_combined_pdf            figures/ch05/fig5_1_combined.pdf
# 8            fig5_1_combined_png            figures/ch05/fig5_1_combined.png
# 3  fig5_1_hidden_t2_recovery_pdf  figures/ch05/fig5_1_hidden_t2_recovery.pdf
# 2  fig5_1_hidden_t2_recovery_png  figures/ch05/fig5_1_hidden_t2_recovery.png
# 5     fig5_1_seen_t4_rollout_pdf     figures/ch05/fig5_1_seen_t4_rollout.pdf
# 4     fig5_1_seen_t4_rollout_png     figures/ch05/fig5_1_seen_t4_rollout.png
# 1   fig5_1_time_pair_designs_pdf   figures/ch05/fig5_1_time_pair_designs.pdf
# 0   fig5_1_time_pair_designs_png   figures/ch05/fig5_1_time_pair_designs.png
# 7       fig5_1_velocity_jump_pdf       figures/ch05/fig5_1_velocity_jump.pdf
# 6       fig5_1_velocity_jump_png       figures/ch05/fig5_1_velocity_jump.png
#
#                                        absolute_path
# 9  /import/macyang_home4/xmabs/flow_matching_for_...
# 8  /import/macyang_home4/xmabs/flow_matching_for_...
# 3  /import/macyang_home4/xmabs/flow_matching_for_...
# 2  /import/macyang_home4/xmabs/flow_matching_for_...
# 5  /import/macyang_home4/xmabs/flow_matching_for_...
# 4  /import/macyang_home4/xmabs/flow_matching_for_...
# 1  /import/macyang_home4/xmabs/flow_matching_for_...
# 0  /import/macyang_home4/xmabs/flow_matching_for_...
# 7  /import/macyang_home4/xmabs/flow_matching_for_...
# 6  /import/macyang_home4/xmabs/flow_matching_for_...
# Panel data sources
#                         panel             source_dataframe  \
# 0  Training time-pair designs              panel schematic
# 1         Hidden t=2 recovery      fig5_1_hidden_t2_values
# 2            Seen t=4 rollout        fig5_1_seen_t4_values
# 3  Velocity jump at hand-offs  fig5_1_velocity_jump_values
#
#                                         source_table
# 0  adjacent_pairs and skip_pairs defined in this ...
# 1         tab_5_1_main_suite.csv / section51_metrics
# 2         tab_5_1_main_suite.csv / section51_metrics
# 3       tab_5_1_main_suite_diag.csv / section51_diag
# Hidden t=2 recovery values
#                        method     target     metric      mean       sem  \
# 0       Pairwise local bridge  hidden_t2    mmd_rbf  0.083634  0.001452
# 1       Pairwise local bridge  hidden_t2  sliced_w2  0.408452  0.004814
# 2  Shared adjacent-only field  hidden_t2    mmd_rbf  0.056502  0.003483
# 3  Shared adjacent-only field  hidden_t2  sliced_w2  0.355996  0.013849
# 4  Shared adjacent+skip field  hidden_t2    mmd_rbf  0.067479  0.005572
# 5  Shared adjacent+skip field  hidden_t2  sliced_w2  0.384300  0.008058
#
#          sd  n_seeds            source_table         error_bar
# 0  0.002516        3  tab_5_1_main_suite.csv  SEM across seeds
# 1  0.008338        3  tab_5_1_main_suite.csv  SEM across seeds
# 2  0.006033        3  tab_5_1_main_suite.csv  SEM across seeds
# 3  0.023987        3  tab_5_1_main_suite.csv  SEM across seeds
# 4  0.009651        3  tab_5_1_main_suite.csv  SEM across seeds
# 5  0.013958        3  tab_5_1_main_suite.csv  SEM across seeds
# Seen t=4 rollout values
#                        method   target       metric      mean       sem  \
# 0       Pairwise local bridge  seen_t4    sliced_w2  0.172061  0.021686
# 1       Pairwise local bridge  seen_t4  centroid_l2  0.582460  0.067813
# 2  Shared adjacent-only field  seen_t4    sliced_w2  0.321605  0.080824
# 3  Shared adjacent-only field  seen_t4  centroid_l2  0.904182  0.190381
# 4  Shared adjacent+skip field  seen_t4    sliced_w2  0.214999  0.022097
# 5  Shared adjacent+skip field  seen_t4  centroid_l2  0.663832  0.112625
#
#          sd  n_seeds            source_table         error_bar
# 0  0.037561        3  tab_5_1_main_suite.csv  SEM across seeds
# 1  0.117455        3  tab_5_1_main_suite.csv  SEM across seeds
# 2  0.139992        3  tab_5_1_main_suite.csv  SEM across seeds
# 3  0.329750        3  tab_5_1_main_suite.csv  SEM across seeds
# 4  0.038274        3  tab_5_1_main_suite.csv  SEM across seeds
# 5  0.195072        3  tab_5_1_main_suite.csv  SEM across seeds
# Velocity jump values
#                        method boundary                 metric      mean  \
# 0       Pairwise local bridge       t1  velocity_jump_mean_l2  8.032818
# 1  Shared adjacent-only field       t1  velocity_jump_mean_l2  8.135409
# 2  Shared adjacent+skip field       t1  velocity_jump_mean_l2  9.122618
# 3       Pairwise local bridge       t3  velocity_jump_mean_l2  8.657238
# 4  Shared adjacent-only field       t3  velocity_jump_mean_l2  4.805779
# 5  Shared adjacent+skip field       t3  velocity_jump_mean_l2  4.451229
#
#         sem        sd  n_seeds                 source_table         error_bar
# 0  0.014671  0.025411        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 1  0.026908  0.046606        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 2  0.068071  0.117903        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 3  0.055341  0.095853        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 4  0.009419  0.016314        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# 5  0.125653  0.217638        3  tab_5_1_main_suite_diag.csv  SEM across seeds
# Missing methods or metrics: none
# Combined figure generated: figures/ch05/fig5_1_combined.png
